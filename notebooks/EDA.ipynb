# %%
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 2.3 MB/s eta 0:00:0000:0100:01
# ...

# %%
import pandas

# %%
patient_list = pandas.read_csv('data/Patient List KE.csv')
print(patient_list.shape)
patient_list.head()
# Out:
# (850, 31)
#   Customer No.  Id                   System Generated ID  EMR Person Id  \
# 0    CKE030015   3  f1aee3ad-d378-4f65-877b-5814a658c0b1           2423
# 1    CKE030016   4  62bc6318-1b76-4284-bf01-90c782228e36          13315
# 2    CKE030017   5  f6715a4e-887b-4abd-a47d-99e4ef93ff02          20602
# 3    CKE030018   6  a36b2a79-58ef-4a09-89ce-7d78d4938d5a          32145
# 4    CKE030019   8  09bb2805-cf40-46aa-ac1c-af0e87487655          51107
#
#   CCC Patient Identifier  prediction_score First Name Last Name  Facility  \
# 0            15204-02872               9.0       JANE    MWANGI   15204.0
# 1            15204-04852               9.0    CHARLES   IKHUNGU   15204.0
# 2            15204-07464               9.0    WILLIAM     KIGEN   15204.0
# 3            16161-02209               9.0     KASIFA    WEKESA   16161.0
# 4            15204-13123               9.0    CHARLES    MWANGI   15204.0
#
#   Medication Type  ... Created By         Created On Modified By  \
# ...

# %%
delivery_tracker = pandas.read_csv('data/Project Beyond Delivery Tracker.csv')
print(delivery_tracker.shape)
delivery_tracker.head()
# Out:
# (178, 18)
#   Delivery Date       CCC_No Facility Customer Sales Order Number Product  \
# 0    18/04/2024  15204-33690     MTRH              KE/SO/24/51639     PBT
# 1    24/04/2024  15204-06818     MTRH              KE/SO/24/55221     PBT
# 2    24/04/2024  15204-41041     MTRH              KE/SO/24/55224     PBT
# 3    24/04/2024  15204-39489     MTRH              KE/SO/24/55223     PBT
# 4    24/04/2024  15204-08234     MTRH              KE/SO/24/55222     PBT
#
#   Client Available during First Call Attempt  Number of Call Attempts  \
# 0                                         NO                        2
# 1                                        YES                        2
# 2                                         NO                        3
# 3                                        YES                        1
# 4                                        YES                        1
#
#    Number of SMS Sent Rescheduled Appointment Escalated to AMPATH  \
# ...

# %%
# find out how many records are matching between the two datasets with CCC_No from delivery_tracker and CCC Patient Identifier from patient_list
matching_records = delivery_tracker.merge(patient_list, left_on='CCC_No', right_on='CCC Patient Identifier')
print(matching_records.shape)
matching_records.head()
# Out:
# (170, 49)
#   Delivery Date       CCC_No Facility_x Customer Sales Order Number Product  \
# 0    18/04/2024  15204-33690       MTRH              KE/SO/24/51639     PBT
# 1    24/04/2024  15204-06818       MTRH              KE/SO/24/55221     PBT
# 2    24/04/2024  15204-41041       MTRH              KE/SO/24/55224     PBT
# 3    24/04/2024  15204-39489       MTRH              KE/SO/24/55223     PBT
# 4    24/04/2024  15204-08234       MTRH              KE/SO/24/55222     PBT
#
#   Client Available during First Call Attempt  Number of Call Attempts  \
# 0                                         NO                        2
# 1                                        YES                        2
# 2                                         NO                        3
# 3                                        YES                        1
# 4                                        YES                        1
#
#    Number of SMS Sent Rescheduled Appointment Escalated to AMPATH  ...  \
# ...

# %%
import pandas
predictions = pandas.read_csv('data/appointments_202301_to_202412_predictions.csv')
print(predictions.shape)
predictions.head()
# Out:
# (34791, 11)
#    person_id gender risk_tier       Encounter_Date Next_clinical_appointment  \
# 0     100013      F      High  2022-11-03 14:56:04       2023-01-26 00:00:00
# 1     100013      F      High  2023-02-01 13:16:37       2023-04-26 00:00:00
# 2     100013      F      High  2023-06-15 14:40:59       2023-09-13 00:00:00
# 3     100013      F      High  2023-07-12 11:31:01       2023-09-05 00:00:00
# 4    1000304      F      High  2022-08-18 14:04:35       2023-02-14 00:00:00
#
#    adherence_predicted    next_actual_visit  days_diff adherence_actual  \
# 0                    1  2023-02-01 13:16:37          6          On Time
# 1                    1  2023-06-15 14:40:59         50         Late/IIT
# 2                    1  2023-07-12 11:31:01        -63          On Time
# 3                    1  2023-11-10 12:53:33         66         Late/IIT
# 4                    0  2022-11-17 13:00:28        -89          On Time
#
#    overall_appointment_success Current_WHO_HIV_Stage
# ...

# %%
predictions['person_id'].unique().shape
# Out:
# (4268,)

# %%
predictions['adherence_predicted'].value_counts()
# Out:
# adherence_predicted
# 1    18792
# 0    15999
# Name: count, dtype: int64

# %%
predictions['adherence_actual'].value_counts()
# Out:
# adherence_actual
# On Time     33966
# Late/IIT      825
# Name: count, dtype: int64
